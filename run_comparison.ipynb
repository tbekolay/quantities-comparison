# %%
# %matplotlib inline

# %%
import run_comparison
results = run_comparison.get_pandas()
# Out:
# BenchAstropy
# BenchDimensions
# BenchDimpy
# BenchMagnitude
# BenchNumericalunits
# BenchPhysicalQuantities
# BenchPint
# BenchPiquant
# BenchQuantities
# BenchScimath
# BenchUnum

# %%
results['facts']
# Out:
#                       First release Implementation   LOC Most recent release  \
# SP.PhysicalQuantities       2005-12      Container   486             2012-10
# astropy.units               2013-01      Container  3448             2013-05
# dimensions.py               2010-07      Container   403             2010-07
# dimpy                       2008-08      Container  1900             2008-08
# magnitude                   2010-05      Container   483             2010-05
# numericalunits              2012-07        Unique!   270             2013-06
# pint                        2012-07      Container  2914             2014-02
# piquant                     2008-05       Subclass  5888             2008-05
# quantities                  2009-10       Subclass  7030             2011-09
# scimath                     2009-03       Subclass  4488             2013-03
# unum                           2000      Container   778             2010-06
#
#                                  PyPI  \
# SP.PhysicalQuantities           False
# astropy.units                 astropy
# dimensions.py                   False
# dimpy                           False
# magnitude                   magnitude
# numericalunits         numericalunits
# pint                             pint
# piquant                       piquant
# quantities                 quantities
# scimath                       scimath
# unum                             unum
#
#                                                                      URL  \
# SP.PhysicalQuantities     https://bitbucket.org/khinsen/scientificpython
# astropy.units          https://astropy.readthedocs.org/en/latest/unit...
# dimensions.py          http://code.activestate.com/recipes/577333-num...
# dimpy                          http://www.inference.phy.cam.ac.uk/db410/
# magnitude                http://juanreyero.com/open/magnitude/index.html
# numericalunits              https://github.com/sbyrnes321/numericalunits
# pint                             https://pint.readthedocs.org/en/latest/
# piquant                http://sourceforge.net/p/piquant/code/HEAD/tre...
# quantities                           http://pythonhosted.org/quantities/
# scimath                               http://docs.enthought.com/scimath/
# unum                           http://home.scarlet.be/be052320/Unum.html
#
#                                                                    hg
# SP.PhysicalQuantities  https://bitbucket.org/khinsen/scientificpython
# astropy.units                                                    None
# dimensions.py                                                    None
# dimpy                                                            None
# magnitude                                                        None
# numericalunits                                                   None
# pint                                                             None
# piquant                                                          None
# quantities                                                       None
# scimath                                                          None
# unum                                                             None
#
# [11 rows x 7 columns]

# %%
results['syntax']
# Out:
#                               make          print
# SP.PhysicalQuantities  constructor          5.0 m
# astropy.units             multiply          5.0 m
# dimensions.py          constructor    Q(5.0, 'm')
# dimpy                     multiply          5.0 m
# magnitude              constructor       5.0000 m
# numericalunits            multiply  2.90241465611
# pint                      multiply      5.0 meter
# piquant                   multiply          5.0 m
# quantities                multiply          5.0 m
# scimath                constructor            5.0
# unum                      multiply        5.0 [m]
#
# [11 rows x 2 columns]

# %%
results['compatibility']['syntax']
# Out:
#                                      print  shape
# SP.PhysicalQuantities        [5.0, 10.0] m  False
# astropy.units                [  5.  10.] m   (2,)
# dimensions.py          Q([5.0, 10.0], 'm')  False
# dimpy                                False  False
# magnitude                            False  False
# numericalunits                       False  False
# pint                     [  5.  10.] meter   (2,)
# piquant                        [5.0, 10.0]  False
# quantities                   [  5.  10.] m   (2,)
# scimath                        [  5.  10.]   (2,)
# unum                       [5.0, 10.0] [m]  False
#
# [11 rows x 2 columns]

# %%
results['compatibility']['unary_ops']
# Out:
#                         abs   neg   pos
# SP.PhysicalQuantities  True  True  True
# astropy.units          True  True  True
# dimensions.py          True  True  True
# dimpy                  True  True  True
# magnitude              True  True  True
# numericalunits         True  True  True
# pint                   True  True  True
# piquant                True  True  True
# quantities             True  True  True
# scimath                True  True  True
# unum                   True  True  True
#
# [11 rows x 3 columns]

# %%
results['compatibility']['binary_same_ops']
# Out:
#                         add   div     eq floordiv     ge     gt     le     lt  \
# SP.PhysicalQuantities  True  True  False    False  False  False  False  False
# astropy.units          True  True   True     True   True   True   True   True
# dimensions.py          True  True   True    False  False   True  False   True
# dimpy                  True  True   True    False   True   True   True   True
# magnitude              True  True  False    False  False  False  False  False
# numericalunits         True  True   True     True   True   True   True   True
# pint                   True  True   True     True   True   True   True   True
# piquant                True  True   True     True   True   True   True   True
# quantities             True  True   True     True   True   True   True   True
# scimath                True  True   True     True   True   True   True   True
# unum                   True  True   True     True  False   True  False   True
#
#                          mod   mul     ne    pow   sub truediv
# SP.PhysicalQuantities  False  True  False  False  True   False
# astropy.units           True  True   True  False  True    True
# dimensions.py          False  True  False  False  True    True
# dimpy                   True  True   True  False  True    True
# magnitude               True  True  False  False  True   False
# numericalunits          True  True   True   True  True    True
# pint                   False  True   True  False  True    True
# piquant                 True  True   True   True  True    True
# quantities              True  True   True  False  True    True
# scimath                 True  True   True  False  True    True
# unum                   False  True  False  False  True    True
#
# [11 rows x 14 columns]

# %%
results['compatibility']['binary_compatible_ops']
# Out:
#                         add   div     eq floordiv     ge     gt     le     lt  \
# SP.PhysicalQuantities  True  True  False    False  False  False  False  False
# astropy.units          True  True   True     True   True   True   True   True
# dimensions.py          True  True   True    False  False   True  False   True
# dimpy                  True  True   True    False   True   True   True   True
# magnitude              True  True  False    False  False  False  False  False
# numericalunits         True  True   True     True   True   True   True   True
# pint                   True  True   True     True   True   True   True   True
# piquant                True  True   True     True   True   True   True   True
# quantities             True  True   True    False   True   True   True   True
# scimath                True  True   True     True   True   True   True   True
# unum                   True  True   True     True  False   True  False   True
#
#                          mod   mul     ne    pow   sub truediv
# SP.PhysicalQuantities  False  True  False  False  True   False
# astropy.units           True  True   True  False  True    True
# dimensions.py          False  True  False  False  True    True
# dimpy                   True  True   True  False  True    True
# magnitude               True  True  False  False  True   False
# numericalunits          True  True   True   True  True    True
# pint                   False  True   True  False  True    True
# piquant                 True  True   True   True  True    True
# quantities              True  True   True  False  True    True
# scimath                 True  True   True  False  True    True
# unum                   False  True  False  False  True    True
#
# [11 rows x 14 columns]

# %%
results['compatibility']['binary_different_ops']
# Out:
#                          add   div     eq floordiv     ge     gt     le  \
# SP.PhysicalQuantities  False  True  False    False  False  False  False
# astropy.units          False  True  False     True  False  False  False
# dimensions.py          False  True  False    False  False  False  False
# dimpy                  False  True   True    False  False  False  False
# magnitude              False  True  False    False  False  False  False
# numericalunits          True  True   True     True   True   True   True
# pint                   False  True   True     True  False  False  False
# piquant                 True  True   True     True   True   True   True
# quantities             False  True   True    False  False  False  False
# scimath                False  True   True     True  False  False  False
# unum                   False  True  False     True  False  False  False
#
#                           lt    mod   mul     ne    pow    sub truediv
# SP.PhysicalQuantities  False  False  True  False  False  False   False
# astropy.units          False  False  True  False  False  False    True
# dimensions.py          False  False  True  False  False  False    True
# dimpy                  False  False  True   True  False  False    True
# magnitude              False   True  True  False  False  False   False
# numericalunits          True   True  True   True   True   True    True
# pint                   False  False  True   True  False  False    True
# piquant                 True   True  True   True   True   True    True
# quantities             False  False  True   True  False  False    True
# scimath                False   True  True   True  False  False    True
# unum                   False  False  True  False  False  False    True
#
# [11 rows x 14 columns]

# %%
results['compatibility']['unary_ufuncs']
# Out:
#                       absolute arccos arccosh arcsin arcsinh arctan arctanh  \
# SP.PhysicalQuantities     True  False   False  False   False  False   False
# astropy.units             True  False   False  False   False  False   False
# dimensions.py             True  False   False  False   False  False   False
# dimpy                     True  False   False  False   False  False   False
# magnitude                 True  False   False  False   False  False   False
# numericalunits            True   True    True   True    True   True    True
# pint                      True  False   False  False   False  False   False
# piquant                   True   True    True   True    True   True    True
# quantities                True  False   False  False   False  False   False
# scimath                   True   True    True   True    True   True    True
# unum                      True  False   False  False   False  False   False
#
#                         ceil conjugate    cos   cosh deg2rad    exp   exp2  \
# SP.PhysicalQuantities  False     False  False  False   False  False  False
# astropy.units           True      True  False  False   False  False  False
# dimensions.py          False     False  False  False   False  False  False
# dimpy                  False     False  False  False   False  False  False
# magnitude              False     False  False  False   False  False  False
# numericalunits          True      True   True   True    True   True   True
# pint                    True      True  False  False   False  False  False
# piquant                 True      True   True   True    True   True   True
# quantities              True      True  False  False   False  False  False
# scimath                 True      True   True   True    True   True   True
# unum                   False     False  False  False   False  False  False
#
#                        expm1  floor    log  log10  log1p   log2
# SP.PhysicalQuantities  False  False  False  False  False  False ...
# astropy.units          False   True  False  False  False  False ...
# dimensions.py          False  False  False  False  False  False ...
# dimpy                  False  False  False  False  False  False ...
# magnitude              False  False  False  False  False  False ...
# numericalunits          True   True   True   True   True   True ...
# pint                   False   True  False  False  False  False ...
# piquant                 True   True   True   True   True   True ...
# quantities             False   True  False  False  False  False ...
# scimath                 True   True   True   True   True   True ...
# unum                   False  False  False  False  False  False ...
#
# [11 rows x 33 columns]

# %%
results['compatibility']['binary_same_ufuncs']
# Out:
#                         add arctan2 divide  equal floor_divide   fmod greater  \
# SP.PhysicalQuantities  True   False   True  False        False  False   False
# astropy.units          True    True   True   True         True   True    True
# dimensions.py          True   False   True  False        False  False   False
# dimpy                  True   False   True   True        False  False    True
# magnitude              True   False   True  False        False  False   False
# numericalunits         True    True   True   True         True   True    True
# pint                   True    True   True   True         True   True    True
# piquant                True    True   True   True         True   True    True
# quantities             True    True   True  False         True   True   False
# scimath                True    True   True   True         True   True    True
# unum                   True   False   True   True         True  False    True
#
#                       greater_equal  hypot   less less_equal logaddexp  \
# SP.PhysicalQuantities         False  False  False      False     False
# astropy.units                  True   True   True       True     False
# dimensions.py                 False  False  False      False     False
# dimpy                          True  False   True       True     False
# magnitude                     False  False  False      False     False
# numericalunits                 True   True   True       True      True
# pint                           True   True   True       True     False
# piquant                        True   True   True       True      True
# quantities                    False   True  False      False     False
# scimath                        True   True   True       True      True
# unum                           True  False   True       True     False
#
#                       logaddexp2 maximum minimum multiply not_equal  power  \
# SP.PhysicalQuantities      False   False   False     True     False  False
# astropy.units              False    True    True     True      True  False
# dimensions.py              False   False   False     True     False  False
# dimpy                      False    True    True     True      True  False
# magnitude                  False   False   False     True     False  False
# numericalunits              True    True    True     True      True   True
# pint                       False    True    True     True      True   True
# piquant                     True    True    True     True      True   True
# quantities                 False   False   False     True     False  False
# scimath                     True    True    True     True      True   True
# unum                       False    True    True     True      True  False
#
#                       remainder subtract
# SP.PhysicalQuantities     False     True ...
# astropy.units              True     True ...
# dimensions.py             False     True ...
# dimpy                      True     True ...
# magnitude                  True     True ...
# numericalunits             True     True ...
# pint                       True     True ...
# piquant                    True     True ...
# quantities                 True     True ...
# scimath                    True     True ...
# unum                      False     True ...
#
# [11 rows x 21 columns]

# %%
results['compatibility']['binary_compatible_ufuncs']
# Out:
#                          add arctan2 divide  equal floor_divide   fmod  \
# SP.PhysicalQuantities   True   False   True  False        False  False
# astropy.units           True    True   True   True         True   True
# dimensions.py           True   False   True  False        False  False
# dimpy                   True   False   True   True        False  False
# magnitude               True   False   True  False        False  False
# numericalunits          True    True   True   True         True   True
# pint                    True    True   True   True         True   True
# piquant                 True    True   True   True         True   True
# quantities             False   False   True  False        False  False
# scimath                 True    True   True   True         True   True
# unum                    True   False   True   True         True  False
#
#                       greater greater_equal  hypot   less less_equal  \
# SP.PhysicalQuantities   False         False  False  False      False
# astropy.units            True          True   True   True       True
# dimensions.py           False         False  False  False      False
# dimpy                    True          True  False   True       True
# magnitude               False         False  False  False      False
# numericalunits           True          True   True   True       True
# pint                     True          True   True   True       True
# piquant                  True          True   True   True       True
# quantities              False         False  False  False      False
# scimath                  True          True   True   True       True
# unum                     True          True  False   True       True
#
#                       logaddexp logaddexp2 maximum minimum multiply not_equal  \
# SP.PhysicalQuantities     False      False   False   False     True     False
# astropy.units             False      False    True    True     True      True
# dimensions.py             False      False   False   False     True     False
# dimpy                     False      False    True    True     True      True
# magnitude                 False      False   False   False     True     False
# numericalunits             True       True    True    True     True      True
# pint                      False      False    True    True     True      True
# piquant                    True       True    True    True     True      True
# quantities                False      False   False   False     True     False
# scimath                    True       True    True    True     True      True
# unum                      False      False    True    True     True      True
#
#                        power remainder subtract
# SP.PhysicalQuantities  False     False     True ...
# astropy.units          False      True     True ...
# dimensions.py          False     False     True ...
# dimpy                  False      True     True ...
# magnitude              False      True     True ...
# numericalunits          True      True     True ...
# pint                    True      True     True ...
# piquant                 True      True     True ...
# quantities             False     False    False ...
# scimath                 True      True     True ...
# unum                   False     False     True ...
#
# [11 rows x 21 columns]

# %%
results['compatibility']['binary_different_ufuncs']
# Out:
#                          add arctan2 divide  equal floor_divide   fmod  \
# SP.PhysicalQuantities  False   False   True  False        False  False
# astropy.units          False   False   True  False         True  False
# dimensions.py          False   False   True  False        False  False
# dimpy                  False   False   True   True        False  False
# magnitude              False   False   True  False        False  False
# numericalunits          True    True   True   True         True   True
# pint                   False   False   True  False         True   True
# piquant                 True    True   True   True         True   True
# quantities             False   False   True  False        False  False
# scimath                 True    True   True   True         True   True
# unum                   False   False   True  False         True  False
#
#                       greater greater_equal  hypot   less less_equal  \
# SP.PhysicalQuantities   False         False  False  False      False
# astropy.units           False         False  False  False      False
# dimensions.py           False         False  False  False      False
# dimpy                   False         False  False  False      False
# magnitude               False         False  False  False      False
# numericalunits           True          True   True   True       True
# pint                    False         False  False  False      False
# piquant                  True          True   True   True       True
# quantities              False         False  False  False      False
# scimath                  True          True   True   True       True
# unum                    False         False  False  False      False
#
#                       logaddexp logaddexp2 maximum minimum multiply not_equal  \
# SP.PhysicalQuantities     False      False   False   False     True     False
# astropy.units             False      False   False   False     True     False
# dimensions.py             False      False   False   False     True     False
# dimpy                     False      False   False   False     True     False
# magnitude                 False      False   False   False     True     False
# numericalunits             True       True    True    True     True      True
# pint                      False      False    True    True     True     False
# piquant                    True       True    True    True     True      True
# quantities                False      False   False   False     True     False
# scimath                    True       True    True    True     True      True
# unum                      False      False   False   False     True     False
#
#                        power remainder subtract
# SP.PhysicalQuantities  False     False    False ...
# astropy.units          False     False    False ...
# dimensions.py          False     False    False ...
# dimpy                  False     False    False ...
# magnitude              False      True    False ...
# numericalunits          True      True     True ...
# pint                    True      True    False ...
# piquant                 True      True     True ...
# quantities             False     False    False ...
# scimath                 True      True     True ...
# unum                   False     False    False ...
#
# [11 rows x 21 columns]

# %%
results['compatibility']['other_numpy']
# Out:
#                       argsort concatenate   mean median  sort    std  where
# SP.PhysicalQuantities    True       False  False  False  True  False  False
# astropy.units            True        True   True   True  True   True   True
# dimensions.py            True       False  False  False  True  False   True
# dimpy                    True        True  False  False  True  False   True
# magnitude                True       False  False  False  True  False  False
# numericalunits           True        True   True   True  True   True   True
# pint                     True        True   True   True  True   True   True
# piquant                  True        True   True   True  True   True   True
# quantities               True        True   True   True  True   True   True
# scimath                  True        True   True   True  True  False   True
# unum                     True        True  False  False  True  False   True
#
# [11 rows x 7 columns]

# %%
results['speed']['mean'].sort_index(ascending=False).plot(kind='barh')

# %%
results['speed']['std'].sort_index(ascending=False).plot(kind='barh')

# %%
results['speed']['np_rel'].sort_index(ascending=False).plot(kind='barh')
